# %%
import pandas as pd
import glob
pd.set_option("display.max_columns", None)

caminho = r"R:\TI\TELEFONIA\Mailings Prontos\2023\Outubro\5\jorgean\Base de cobranca\base cobranca gevenue\BASE_COBRANCA_20231003_T_ATN_3356/BASE_COBRANCA_20231003_T_ATN_3356.txt"
arquivos = glob.glob(caminho + "/*.txt")

lista_de_larguras =[15,12,15,40,8,15,10,50,16,16,16,16,30,10,12,12,12,12,12,12,12,10,10,50,50,50,50,10,300,40,2,9,10,300,40,2,9,2,10,2,10,2,10,2,10,2,10,2,10,2,10,2,10]

header_novo_gevenue = [
    "CÓDIGO DA CONTA",
    "SENHA",    "PRODUTO",    "NOME",    "TIPO DE PESSOA",    "CPF/CNPJ",
    "DATA_NASCIMENTO",    "FILA_COBRANCA",    "ULT_DATA_SMS",    "ULT_DATA_CARTA",
    "ULT_DATA_URA",    "ULT_DATA_EMAIL",    "CARTEIRA (REGIÃO)",    "VENCIMENTO",    "Valor Claro Móvel",
    "Valor Claro Residencial",    "Valor Claro Empresarial",    "Valor Claro Fixo",    "Valor Claro TV",
    "Valor TvExpurgo",    "Valor Oi",    "DATA_NEGATIVACAO",    "DATA_CADASTRO",    "STATUS_CONTRATO_NET",
    "EMAIL_01",    "EMAIL_02",    "EMAIL_03",    "TIPO_DE_ENDERECO_1",
    "ORIGEM_ENDERECO_1",    "CIDADE_END_INS",    "ESTADO_END_INS",    "CEP_END_INS",    "TIPO_DE_ENDERECO_2",
    "ORIGEM_ENDERECO_2",    "CIDADE_END_FAT",    "UF_END_FAT",    "CEP_END_FAT",    "DDD_FIXO_1",
    "TEL_FIXO_1",    "DDD_FIXO_2",    "TEL_FIXO_2",    "DDD_FIXO_3",    "TEL_FIXO_3",
    "DDD_FIXO_4",    "TEL_FIXO_4",    "DDD_CEL_1",    "TEL_CEL_1",    "DDD_CEL_2",
    "TEL_CEL_2",    "DDD_CEL_3",    "TEL_CEL_3",    "DDD_CEL_4",    "TEL_CEL_4"]


base_gevenue = pd.read_fwf(caminho, encoding='utf-8',sep='\t',widths = lista_de_larguras ,names = header_novo_gevenue,dtype='str')



# Criando DataFrame com concat e a lista criada a cima


base_gevenue
# Out:
#       CÓDIGO DA CONTA     SENHA      PRODUTO  \
# 0        007010637818   5886588  NetTvVirtua
# 1        007010643109   5886590  NetTvVirtua
# 2        007010645870   5886591  NetTvVirtua
# 3        007010649972   5886593  NetTvVirtua
# 4        007010654852   5886594  NetTvVirtua
# ...               ...       ...          ...
# 66669    162384618731  11051459      NetFone
# 66670    162384805175  11051581      NetFone
# 66671    162385105100  11051689      NetFone
# 66672    162384447996  11051905      NetFone
# 66673    162384917186  11051916      NetFone
#
#                                     NOME TIPO DE PESSOA        CPF/CNPJ  \
# 0             TELMA GOMES SILVA DE ASSIS       Pessoa F     30509585884
# 1              RAFAEL CRISTIANO DA SILVA       Pessoa F     40499773896
# 2          EVELYN AVELINO DE JESUS SILVA       Pessoa F     44761509856
# 3        JOSE HAMILTON VIEIRA DOS SANTOS       Pessoa F     06092874865
# 4               DAVID LUCIO GOMES PELUZO       Pessoa F     33260053859
# ...                                  ...            ...             ...
# 66669             SANDRO WAGNER CARVALHO         FISICA     33796539858
# 66670                 JOEL CARVALHO NETO         FISICA     17881951400
# 66671      GUILHERME RODRIGUES  FERREIRA       JURIDICA  34862703000140
# 66672             ROSANGELA CAMILO CESAR         FISICA     06477831694
# 66673  CIBELE DE CASTRO E SILVA DE JESUS         FISICA     14467254803
#
#       DATA_NASCIMENTO FILA_COBRANCA ULT_DATA_SMS ULT_DATA_CARTA  \
# 0          26/03/1982  Inadimplente          NaN            NaN
# 1          24/06/1991  Inadimplente          NaN            NaN
# 2          16/08/1993  Inadimplente          NaN            NaN
# 3          06/12/1964  Inadimplente          NaN            NaN
# 4          31/10/1985  Inadimplente          NaN            NaN
# ...               ...           ...          ...            ...
# 66669      13/02/1977  Inadimplente          NaN            NaN
# 66670      30/06/1959  Inadimplente          NaN            NaN
# 66671      08/04/1950  Inadimplente          NaN            NaN
# 66672      31/03/1982       Quitado          NaN            NaN
# 66673      06/09/1970  Inadimplente          NaN            NaN
#
#            ULT_DATA_URA ULT_DATA_EMAIL    CARTEIRA (REGIÃO)  VENCIMENTO  \
# 0                   NaN            NaN             SOROCABA  10/07/2013
# 1                   NaN            NaN             SOROCABA  15/04/2014
# 2      22/08/2023 12:59            NaN             SOROCABA  25/04/2018
# 3                   NaN            NaN             SOROCABA  10/04/2013
# 4                   NaN            NaN             SOROCABA  10/05/2013
# ...                 ...            ...                  ...         ...
# 66669               NaN            NaN  SAO JOSE DOS CAMPOS  10/11/2018
# 66670               NaN            NaN  SAO JOSE DOS CAMPOS  10/10/2020
# 66671               NaN            NaN  SAO JOSE DOS CAMPOS  25/02/2020
# 66672  14/09/2023 13:47            NaN  SAO JOSE DOS CAMPOS  10/04/2021
# 66673  22/08/2023 12:32            NaN  SAO JOSE DOS CAMPOS  10/11/2019
#
#       Valor Claro Móvel Valor Claro Residencial Valor Claro Empresarial  \
# 0                  0,00                  119,80                    0,00
# 1                  0,00                  230,89                   84,99
# 2                  0,00                  489,96                    0,00
# 3                  0,00                  196,43                   80,26
# 4                  0,00                  541,04                   79,80
# ...                 ...                     ...                     ...
# 66669              0,00                    0,00                   21,66
# 66670              0,00                    0,00                   10,39
# 66671              0,00                    0,00                   87,98
# 66672              0,00                    0,00                  315,27
# 66673              0,00                    0,00                  267,79
#
#       Valor Claro Fixo Valor Claro TV Valor TvExpurgo Valor Oi  \
# 0                 0,00           0,00            0,00     0,00
# 1                 0,00           0,00            0,00     0,00
# 2                 0,00           0,00            0,00     0,00
# 3                 0,00           0,00            0,00     0,00
# 4                 0,00           0,00            0,00     0,00
# ...                ...            ...             ...      ...
# 66669             0,00           0,00            0,00     0,00
# 66670             0,00           0,00            0,00     0,00
# 66671             0,00           0,00            0,00     0,00
# 66672             0,00           0,00            0,00     0,00
# 66673             0,00           0,00            0,00     0,00
#
#       DATA_NEGATIVACAO DATA_CADASTRO                   STATUS_CONTRATO_NET  \
# 0                  NaN    06/09/2022  DESCONECTADO - INADIMPLENCIA (TOTAL)
# 1                  NaN    06/09/2022  DESCONECTADO - INADIMPLENCIA (TOTAL)
# 2                  NaN    06/09/2022  DESCONECTADO - INADIMPLENCIA (TOTAL)
# 3                  NaN    06/09/2022  DESCONECTADO - INADIMPLENCIA (TOTAL)
# 4                  NaN    06/09/2022  DESCONECTADO - INADIMPLENCIA (TOTAL)
# ...                ...           ...                                   ...
# 66669              NaN    03/04/2023                             CANCELADO
# 66670              NaN    03/04/2023                             CANCELADO
# 66671              NaN    03/04/2023                             CONECTADO
# 66672              NaN    03/04/2023                  DESCONECTADO - OPCAO
# 66673              NaN    03/04/2023                             CANCELADO
#
#                                EMAIL_01 EMAIL_02 EMAIL_03 TIPO_DE_ENDERECO_1  \
# 0          tgtekaloiraposto77@gmail.com      NaN      NaN         Instalação
# 1                                   NaN      NaN      NaN         Instalação
# 2            regina.avelino23@gmail.com      NaN      NaN         Instalação
# 3                                   NaN      NaN      NaN         Instalação
# 4               david,lucio@hotmail.com      NaN      NaN         Instalação
# ...                                 ...      ...      ...                ...
# 66669  sandrovagnercarvalho13@gmail.com      NaN      NaN         Instalação
# 66670       joelcarvalhonetoc@gmail.com      NaN      NaN         Instalação
# 66671              estcs123@hotmail.com      NaN      NaN         Instalação
# 66672         Pretatoquinho@hotmail.com      NaN      NaN         Instalação
# 66673       tidelecastrojesus@gmail.com      NaN      NaN         Instalação
#
#            ORIGEM_ENDERECO_1       CIDADE_END_INS ESTADO_END_INS CEP_END_INS  \
# 0      Faturador de cobrança             SOROCABA             SP    18078610
# 1      Faturador de cobrança             SOROCABA             SP    18066090
# 2      Faturador de cobrança             SOROCABA             SP    18077591
# 3      Faturador de cobrança             SOROCABA             SP    18078260
# 4      Faturador de cobrança             SOROCABA             SP    18103040
# ...                      ...                  ...            ...         ...
# 66669  Faturador de cobrança  SAO JOSE DOS CAMPOS             SP    12211840
# 66670  Faturador de cobrança  SAO JOSE DOS CAMPOS             SP    12236874
# 66671  Faturador de cobrança  SAO JOSE DOS CAMPOS             SP    12231675
# 66672  Faturador de cobrança  SAO JOSE DOS CAMPOS             SP    12225540
# 66673  Faturador de cobrança  SAO JOSE DOS CAMPOS             SP    12228864
#
#       TIPO_DE_ENDERECO_2        ORIGEM_ENDERECO_2       CIDADE_END_FAT  \
# 0               Cobrança  Faturador de instalação             SOROCABA
# 1               Cobrança  Faturador de instalação             SOROCABA
# 2               Cobrança  Faturador de instalação             SOROCABA
# 3               Cobrança  Faturador de instalação             SOROCABA
# 4               Cobrança  Faturador de instalação             SOROCABA
# ...                  ...                      ...                  ...
# 66669           Cobrança  Faturador de instalação  SAO JOSE DOS CAMPOS
# 66670           Cobrança  Faturador de instalação  SAO JOSE DOS CAMPOS
# 66671           Cobrança  Faturador de instalação  SAO JOSE DOS CAMPOS
# 66672           Cobrança  Faturador de instalação  SAO JOSE DOS CAMPOS
# 66673           Cobrança  Faturador de instalação  SAO JOSE DOS CAMPOS
#
#       UF_END_FAT CEP_END_FAT DDD_FIXO_1 TEL_FIXO_1 DDD_FIXO_2 TEL_FIXO_2  \
# 0             SP    18078610        NaN        NaN        NaN        NaN
# 1             SP    18066090        NaN        NaN        NaN        NaN
# 2             SP    18077591         15   32267019        NaN        NaN
# 3             SP    18078260        NaN        NaN        NaN        NaN
# 4             SP    18103040        NaN        NaN        NaN        NaN
# ...          ...         ...        ...        ...        ...        ...
# 66669         SP    12211840         12   32093489        NaN        NaN
# 66670         SP    12236874         12   33220410        NaN        NaN
# 66671         SP    12231675         00   00000000         12   32060544
# 66672         SP    12225540         12   33467147        NaN        NaN
# 66673         SP    12228864         12   33466075        NaN        NaN
#
#       DDD_FIXO_3 TEL_FIXO_3 DDD_FIXO_4 TEL_FIXO_4 DDD_CEL_1  TEL_CEL_1  \
# 0            NaN        NaN        NaN        NaN        15  988077887
# 1            NaN        NaN        NaN        NaN        15  997707764
# 2            NaN        NaN        NaN        NaN       NaN        NaN
# 3            NaN        NaN        NaN        NaN        15  998038831
# 4            NaN        NaN        NaN        NaN        15  997065687
# ...          ...        ...        ...        ...       ...        ...
# 66669        NaN        NaN        NaN        NaN        12  988368073
# 66670        NaN        NaN        NaN        NaN        12  992128881
# 66671        NaN        NaN        NaN        NaN        12  991411458
# 66672        NaN        NaN        NaN        NaN        35  991197664
# 66673        NaN        NaN        NaN        NaN        67  992906505
#
#       DDD_CEL_2  TEL_CEL_2 DDD_CEL_3 TEL_CEL_3 DDD_CEL_4 TEL_CEL_4
# 0           NaN        NaN       NaN       NaN       NaN       NaN
# 1           NaN        NaN       NaN       NaN       NaN       NaN
# 2           NaN        NaN       NaN       NaN       NaN       NaN
# 3           NaN        NaN       NaN       NaN       NaN       NaN
# 4           NaN        NaN       NaN       NaN       NaN       NaN
# ...         ...        ...       ...       ...       ...       ...
# 66669       NaN        NaN       NaN       NaN       NaN       NaN
# 66670       NaN        NaN       NaN       NaN       NaN       NaN
# 66671       NaN        NaN       NaN       NaN       NaN       NaN
# 66672        12  982336079       NaN       NaN       NaN       NaN
# 66673       NaN        NaN       NaN       NaN       NaN       NaN
#
# [66674 rows x 53 columns]
