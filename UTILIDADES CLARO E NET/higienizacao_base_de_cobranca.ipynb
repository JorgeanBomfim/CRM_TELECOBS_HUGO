# %%
#################################### BASE DE COBRANÇA INTERSIC ###############################
import pandas as pd 
import numpy as np
import glob  
import warnings 
import csv
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)

# # Defina as colunas que você deseja carregar
colunas_para_higienizacao = ['CPF_CNPJ','PRODUTO','NOME','TELEFONE','TELEFONE_CONTATO_RESIDENCIAL','TELEFONE_CELULAR','TELEFONE_COMERCIAL','TEL_01','TEL_02','TEL_03','TEL_04','TEL_05','TEL_06','TEL_07','TEL_08','TEL_09','TEL_10','CEL_01','CEL_02','CEL_03','CEL_04','CEL_05','CEL_06','CEL_07','CEL_08','CEL_09','CEL_10','EMAIL_01','EMAIL_02','EMAIL_03']
# Caminho para o arquivo CSV
file_path = r"R:\TI\TELEFONIA\BASES CLARO E NET ATIVA\BASE DE COBRANÇA/BASE_COBRANCA_20240616_ATN_199.txt"

# Opção 1: Use chunksize para ler o arquivo em pedaços
chunk_size = 1000000  # ajuste o tamanho conforme necessário
chunks = pd.read_csv(file_path, sep="\t", dtype=str, encoding='iso-8859-1', engine='python', error_bad_lines=False, warn_bad_lines=True, skiprows=1, chunksize=chunk_size, quoting=csv.QUOTE_NONE,usecols=colunas_para_higienizacao)
base_de_cobranca = pd.concat(chunks, ignore_index=True)

df_1 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TELEFONE','EMAIL_01','EMAIL_02','EMAIL_03']]
df_2 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TELEFONE_CONTATO_RESIDENCIAL','EMAIL_01','EMAIL_02','EMAIL_03']]
df_3 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TELEFONE_CELULAR','EMAIL_01','EMAIL_02','EMAIL_03']]
df_4 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TELEFONE_COMERCIAL','EMAIL_01','EMAIL_02','EMAIL_03']]
df_5 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TEL_01','EMAIL_01','EMAIL_02','EMAIL_03']]
df_6 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TEL_02','EMAIL_01','EMAIL_02','EMAIL_03']]
df_7 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TEL_03','EMAIL_01','EMAIL_02','EMAIL_03']]
df_8 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TEL_04','EMAIL_01','EMAIL_02','EMAIL_03']]
df_9 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TEL_05','EMAIL_01','EMAIL_02','EMAIL_03']]
df_10 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TEL_06','EMAIL_01','EMAIL_02','EMAIL_03']]
df_11 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TEL_07','EMAIL_01','EMAIL_02','EMAIL_03']]
df_12 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TEL_08','EMAIL_01','EMAIL_02','EMAIL_03']]
df_13 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TEL_09','EMAIL_01','EMAIL_02','EMAIL_03']]
df_14 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TEL_10','EMAIL_01','EMAIL_02','EMAIL_03']]
df_15 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','CEL_01','EMAIL_01','EMAIL_02','EMAIL_03']]
df_16 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','CEL_02','EMAIL_01','EMAIL_02','EMAIL_03']]
df_17 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','CEL_03','EMAIL_01','EMAIL_02','EMAIL_03']]
df_18 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','CEL_04','EMAIL_01','EMAIL_02','EMAIL_03']]
df_19 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','CEL_05','EMAIL_01','EMAIL_02','EMAIL_03']]
df_20 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','CEL_06','EMAIL_01','EMAIL_02','EMAIL_03']]
df_21 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','CEL_07','EMAIL_01','EMAIL_02','EMAIL_03']]
df_22 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','CEL_08','EMAIL_01','EMAIL_02','EMAIL_03']]
df_23 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','CEL_09','EMAIL_01','EMAIL_02','EMAIL_03']]
df_24 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','CEL_10','EMAIL_01','EMAIL_02','EMAIL_03']]


df_2 = df_2.rename(columns={'TELEFONE_CONTATO_RESIDENCIAL':'TELEFONE'})
df_3 = df_3.rename(columns={'TELEFONE_CELULAR':'TELEFONE'})
df_4 = df_4.rename(columns={'TELEFONE_COMERCIAL':'TELEFONE'})
df_5 = df_5.rename(columns={'TEL_01':'TELEFONE'})
df_6 = df_6.rename(columns={'TEL_02':'TELEFONE'})
df_7 = df_7.rename(columns={'TEL_03':'TELEFONE'})
df_8 = df_8.rename(columns={'TEL_04':'TELEFONE'})
df_9 = df_9.rename(columns={'TEL_05':'TELEFONE'})
df_10 = df_10.rename(columns={'TEL_06':'TELEFONE'})
df_11 = df_11.rename(columns={'TEL_07':'TELEFONE'})
df_12 = df_12.rename(columns={'TEL_08':'TELEFONE'})
df_13 = df_13.rename(columns={'TEL_09':'TELEFONE'})
df_14 = df_14.rename(columns={'TEL_10':'TELEFONE'})
df_15 = df_15.rename(columns={'CEL_01':'TELEFONE'})
df_16 = df_16.rename(columns={'CEL_02':'TELEFONE'})
df_17 = df_17.rename(columns={'CEL_03':'TELEFONE'})
df_18 = df_18.rename(columns={'CEL_04':'TELEFONE'})
df_19 = df_19.rename(columns={'CEL_05':'TELEFONE'})
df_20 = df_20.rename(columns={'CEL_06':'TELEFONE'})
df_21 = df_21.rename(columns={'CEL_07':'TELEFONE'})
df_22 = df_22.rename(columns={'CEL_08':'TELEFONE'})
df_23 = df_23.rename(columns={'CEL_09':'TELEFONE'})
df_24 = df_24.rename(columns={'CEL_10':'TELEFONE'})

base_de_cobranca = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,df_10,df_11,df_12,df_13,df_14,df_15,df_16,df_17,df_18,df_19,df_20,df_21,df_22,df_23,df_24])

df_1 = ''
df_2 = ''
df_3 = ''
df_4 = ''
df_5 = ''
df_6 = ''
df_7 = ''
df_8 = ''
df_9 = ''
df_10 = ''
df_11 = ''
df_12 = ''
df_13 = ''
df_14 = ''
df_15 = ''
df_16 = ''
df_17 = ''
df_18 = ''
df_19 = ''
df_20 = ''
df_21 = ''
df_22 = ''
df_23 = ''
df_24 = ''

df_1 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TELEFONE','EMAIL_01']].rename(columns={'EMAIL_01':'EMAIL'})
df_2 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TELEFONE','EMAIL_02']].rename(columns={'EMAIL_02':'EMAIL'})
df_3 = base_de_cobranca.loc[:,['PRODUTO','CPF_CNPJ','TELEFONE','EMAIL_03']].rename(columns={'EMAIL_03':'EMAIL'})

base_de_cobranca_intersic = pd.concat([df_1,df_2,df_3]).drop_duplicates(['PRODUTO','CPF_CNPJ','TELEFONE','EMAIL']).reset_index(drop=True)

df_1 = ''
df_2 = ''
df_3 = ''

base_de_cobranca_intersic = base_de_cobranca_intersic.rename(columns={'CPF_CNPJ':'CPF'})
base_de_cobranca_intersic

# %%
base_de_cobranca_intersic.to_csv(r"R:\TI\TELEFONIA\BASES CLARO E NET ATIVA\BASE DE COBRANÇA\BASES COBRANCA PARA HIGIENIZAR/base_de_cobranca_intersic_2106.csv",index=False,sep=';')

# %%
#################################### BASE DE COBRANÇA GEVENUE ###############################
import pandas as pd
import glob

pd.set_option("display.max_columns", None)
#### BASES CLARO COBRANÇA INTERSIC
header_novo_gevenue = ["CÓDIGO DA CONTA","SENHA","PRODUTO","NOME","TIPO DE PESSOA","CPF/CNPJ","DATA_NASCIMENTO","FILA_COBRANCA","ULT_DATA_SMS","ULT_DATA_CARTA",
    "ULT_DATA_URA","ULT_DATA_EMAIL","CARTEIRA (REGIÃO)","VENCIMENTO","Valor Claro Móvel","Valor Claro Residencial","Valor Claro Empresarial","Valor Claro Fixo",
    "Valor Claro TV","Valor TvExpurgo","Valor Oi","DATA_NEGATIVACAO","DATA_CADASTRO","STATUS_CONTRATO_NET","EMAIL_01","EMAIL_02","EMAIL_03","TIPO_DE_ENDERECO_1","ORIGEM_ENDERECO_1",
    "CIDADE_END_INS","ESTADO_END_INS","CEP_END_INS","TIPO_DE_ENDERECO_2","ORIGEM_ENDERECO_2","CIDADE_END_FAT","UF_END_FAT","CEP_END_FAT","DDD_FIXO_1","TEL_FIXO_1","DDD_FIXO_2",
    "TEL_FIXO_2","DDD_FIXO_3","TEL_FIXO_3","DDD_FIXO_4","TEL_FIXO_4","DDD_CEL_1","TEL_CEL_1","DDD_CEL_2","TEL_CEL_2","DDD_CEL_3","TEL_CEL_3","DDD_CEL_4","TEL_CEL_4"]

caminho = r"R:\TI\TELEFONIA\BASES CLARO E NET ATIVA\BASE DE COBRANÇA\Base de Cobrança GEV"
arquivos = glob.glob(caminho + "/*.txt")
#Lista de larguras do layout NET COB
lista_de_larguras = [15,12,15,40,8,15,10,50,16,16,16,16,30,10,12,12,12,12,12,12,12,	10,	10,	50,50,50,50,10,300,40,2,9,10,300,40,2,9,2,10,2,10,2,10,2,10,2,10,2,10,2,10,2,10]

lista = []
for arquivo in arquivos:
    print(arquivo)
    lista.append(arquivo)
    
    dfList = []
    
    for item in lista:   
        chunks = pd.read_fwf(item, encoding='iso-8859-1', chunksize=1000000, sep=";",widths = lista_de_larguras, dtype='str',names=header_novo_gevenue)
        for df in chunks:
            dfList.append(df)

# Criando DataFrame com concat e a lista criada a cima
base_cob_gevenue = pd.concat(dfList, sort=False, ignore_index=False)

df_1 = base_cob_gevenue.loc[:,['PRODUTO','CPF/CNPJ','DDD_FIXO_1','TEL_FIXO_1','EMAIL_01','EMAIL_02','EMAIL_03']]
df_2 = base_cob_gevenue.loc[:,['PRODUTO','CPF/CNPJ','DDD_FIXO_2','TEL_FIXO_2','EMAIL_01','EMAIL_02','EMAIL_03']]
df_3 = base_cob_gevenue.loc[:,['PRODUTO','CPF/CNPJ','DDD_FIXO_3','TEL_FIXO_3','EMAIL_01','EMAIL_02','EMAIL_03']]
df_4 = base_cob_gevenue.loc[:,['PRODUTO','CPF/CNPJ','DDD_FIXO_4','TEL_FIXO_4','EMAIL_01','EMAIL_02','EMAIL_03']]

df_5 = base_cob_gevenue.loc[:,['PRODUTO','CPF/CNPJ','DDD_CEL_1','TEL_CEL_1','EMAIL_01','EMAIL_02','EMAIL_03']]
df_6 = base_cob_gevenue.loc[:,['PRODUTO','CPF/CNPJ','DDD_CEL_2','TEL_CEL_2','EMAIL_01','EMAIL_02','EMAIL_03']]
df_7 = base_cob_gevenue.loc[:,['PRODUTO','CPF/CNPJ','DDD_CEL_3','TEL_CEL_3','EMAIL_01','EMAIL_02','EMAIL_03']]
df_8 = base_cob_gevenue.loc[:,['PRODUTO','CPF/CNPJ','DDD_CEL_4','TEL_CEL_4','EMAIL_01','EMAIL_02','EMAIL_03']]


df_1 = df_1.rename(columns={'DDD_FIXO_1':'DDD', 'TEL_FIXO_1':'TELEFONE'})
df_2 = df_2.rename(columns={'DDD_FIXO_2':'DDD', 'TEL_FIXO_2':'TELEFONE'})
df_3 = df_3.rename(columns={'DDD_FIXO_3':'DDD', 'TEL_FIXO_3':'TELEFONE'})
df_4 = df_4.rename(columns={'DDD_FIXO_4':'DDD', 'TEL_FIXO_4':'TELEFONE'})
df_5 = df_5.rename(columns={'DDD_CEL_1':'DDD', 'TEL_CEL_1':'TELEFONE'})
df_6 = df_6.rename(columns={'DDD_CEL_2':'DDD', 'TEL_CEL_2':'TELEFONE'})
df_7 = df_7.rename(columns={'DDD_CEL_3':'DDD', 'TEL_CEL_3':'TELEFONE'})
df_8 = df_8.rename(columns={'DDD_CEL_4':'DDD', 'TEL_CEL_4':'TELEFONE'})

base_cob_gevenue = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8])

df_1 = ''
df_2 = ''
df_3 = ''
df_4 = ''
df_5 = ''
df_6 = ''
df_7 = ''
df_8 = ''

df_1 = base_cob_gevenue.loc[:,['PRODUTO','CPF/CNPJ','DDD','TELEFONE','EMAIL_01']].rename(columns={'EMAIL_01':'EMAIL'})
df_2 = base_cob_gevenue.loc[:,['PRODUTO','CPF/CNPJ','DDD','TELEFONE','EMAIL_02']].rename(columns={'EMAIL_02':'EMAIL'})
df_3 = base_cob_gevenue.loc[:,['PRODUTO','CPF/CNPJ','DDD','TELEFONE','EMAIL_03']].rename(columns={'EMAIL_03':'EMAIL'})

base_cob_gevenue = pd.concat([df_1,df_2,df_3])

base_cob_gevenue['TELEFONE'] = base_cob_gevenue['DDD'] + base_cob_gevenue['TELEFONE']
base_cob_gevenue = base_cob_gevenue.drop(columns='DDD')

base_cob_gevenue = base_cob_gevenue.rename(columns={'CPF/CNPJ':'CPF'})

# %%
base_cob_gevenue.to_csv(r"R:\TI\TELEFONIA\BASES CLARO E NET ATIVA\BASE DE COBRANÇA\BASES COBRANCA PARA HIGIENIZAR/base_de_cobranca_gevenue_0706.csv",index=False,sep=';')

# %%
#################################### BASE DE COBRANÇA INTERSIC ###############################
import pandas as pd 
import glob  

pd.set_option("display.max_columns", None)


caminho = r"R:\TI\TELEFONIA\BASES CLARO E NET ATIVA\BASE DE COBRANÇA\BASES COBRANCA PARA HIGIENIZAR"
arquivos = glob.glob(caminho + "/*.csv")

lista = []
for arquivo in arquivos:
    print(arquivo)
    lista.append(arquivo)
    
    dfList = []
    
    for item in lista:   
        chunks = pd.read_csv(item, encoding='iso-8859-1', chunksize=1000000, sep=";", dtype='str')
        for df in chunks:
            dfList.append(df)

# Criando DataFrame com concat e a lista criada a cima
bases_cobranca_atual = pd.concat(dfList, sort=False, ignore_index=False)
bases_cobranca_atual

# %%
### MARCANDO OS TELEFONES DA BASE DE COBRANÇA
bases_cobranca_atual = bases_cobranca_atual[['TELEFONE']].assign(TEL_ATIVO='ATIVO').drop_duplicates(['TELEFONE'])

# %%
#################################################### CARERGANDO A BASE QUE FOI NORMALIZADA QUE COMPREENDE A TODAS AS EQUIPES DO HUGO (CLAROS/NET/GEVENUE)

caminho = r"R:\TI\TELEFONIA\BASES CLARO E NET ATIVA\BASES SEMANA PADRAO"
arquivos = glob.glob(caminho + "/*.csv")
lista = []
for arquivo in arquivos:
    print(arquivo)
    lista.append(arquivo)
    
    dfList = []
    
    for item in lista:   
        chunks = pd.read_csv(item, encoding='iso-8859-1', chunksize=1000000, sep=";", dtype='str')
        for df in chunks:
            dfList.append(df)

# Criando DataFrame com concat e a lista criada a cima
df_telecobs_hugo = pd.concat(dfList, sort=False, ignore_index=False)

# %%
df_telecobs_hugo

# %%
bases_cobranca_atual.query("TELEFONE == '6133270195'")

# %%
df_telecobs_hugo = pd.merge(df_telecobs_hugo, bases_cobranca_atual, right_on=['TELEFONE'], left_on=['TELEFONE'], how="left")

# %%
df_telecobs_hugo.query("TEL_ATIVO.isnull()")
